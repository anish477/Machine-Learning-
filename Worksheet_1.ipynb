# %% [markdown]
# <a href="https://colab.research.google.com/github/anish477/Machine-Learning-/blob/main/Worksheet_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from PIL import Image
imaged_colred=Image.open("/content/drive/MyDrive/Ai Herald/worksheet_1/Lenna_(test_image).png")
display(imaged_colred)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512>

# %%
import numpy as np
image_array=np.array(imaged_colred)
height,weidth= imaged_colred.size
channels=len(imaged_colred.getbands())
print(f'the shape of colored image is {height} and weidht is {weidth}')
print(f'the total zize of image is {height*weidth*channels}')

print(f'the shape of colored image array is {image_array.size}')

##display the top corner of 100x100 pixel

print(f'The top corner of 100x100 is {image_array[:100,:100]}')
# Out:
# the shape of colored image is 512 and weidht is 512
# the total zize of image is 786432
# the shape of colored image array is 786432
# The top corner of 100x100 is [[[226 137 125]
#   [226 137 125]
#   [223 137 133]
#   ...
#   [179  79  86]
#   [178  78  93]
#   [174  78  87]]
#
#  [[226 137 125]
#   [226 137 125]
#   [223 137 133]
#   ...
#   [179  79  86]
#   [178  78  93]
#   [174  78  87]]
#
#  [[226 137 125]
#   [226 137 125]
#   [223 137 133]
#   ...
#   [179  79  86]
#   [178  78  93]
#   [174  78  87]]
#
#  ...
#
#  [[177  64  79]
#   [177  64  79]
#   [163  58  74]
#   ...
#   [177  65  79]
#   [172  68  79]
#   [172  75  83]]
#
#  [[169  63  79]
#   [169  63  79]
#   [159  53  74]
#   ...
#   [175  70  85]
#   [178  72  84]
#   [178  63  75]]
#
#  [[166  55  74]
#   [166  55  74]
#   [154  51  71]
#   ...
#   [178  65  78]
#   [175  67  79]
#   [177  59  79]]]

# %%
#Showig three color channel
import matplotlib.pyplot as plt

red_colored_channel=image_array[:,:,0]
print(f'red channel {red_colored_channel}')
# print(Image.fomrarray(red_colored_channel))
print("\n")
print(f'the green channel{image_array[:,:,1]}')
print("\n")
print(f'the blue channel{image_array[:,:,2]}')
print("\n")
# print(f'the for alpha value channel{image_array[:,:,3]}')
plt.imshow(red_colored_channel)
# Out:
# red channel [[226 226 223 ... 230 221 200]
#  [226 226 223 ... 230 221 200]
#  [226 226 223 ... 230 221 200]
#  ...
#  [ 84  84  92 ... 173 172 177]
#  [ 82  82  96 ... 179 181 185]
#  [ 82  82  96 ... 179 181 185]]
#
#
# the green channel[[137 137 137 ... 148 130  99]
#  [137 137 137 ... 148 130  99]
#  [137 137 137 ... 148 130  99]
#  ...
#  [ 18  18  27 ...  73  68  62]
#  [ 22  22  32 ...  70  71  74]
#  [ 22  22  32 ...  70  71  74]]
#
#
# the blue channel[[125 125 133 ... 122 110  90]
#  [125 125 133 ... 122 110  90]
#  [125 125 133 ... 122 110  90]
#  ...
#  [ 60  60  58 ...  84  76  79]
#  [ 57  57  62 ...  79  81  81]
#  [ 57  57  62 ...  79  81  81]]

# %%
plt.imshow(image_array[:,:,1])

# %%
plt.imshow(image_array[:,:,2])

# %% [markdown]
# *italicized text*

# %%
k=image_array[:50,:50]
print(f'The top corner of 100x100 is {k}')
grayImage=Image.fromarray(k)
display(grayImage)
# Out:
# The top corner of 100x100 is [[[226 137 125]
#   [226 137 125]
#   [223 137 133]
#   ...
#   [231 149 121]
#   [237 149 119]
#   [238 149 116]]
#
#  [[226 137 125]
#   [226 137 125]
#   [223 137 133]
#   ...
#   [231 149 121]
#   [237 149 119]
#   [238 149 116]]
#
#  [[226 137 125]
#   [226 137 125]
#   [223 137 133]
#   ...
#   [231 149 121]
#   [237 149 119]
#   [238 149 116]]
#
#  ...
#
#  [[230 137 125]
#   [230 137 125]
#   [229 134 107]
#   ...
#   [233 145 119]
#   [233 138 116]
#   [233 133 102]]
#
#  [[230 139 115]
#   [230 139 115]
#   [228 136 107]
#   ...
#   [230 136 113]
#   [231 140 118]
#   [235 137 109]]
#
#  [[231 137 119]
#   [231 137 119]
#   [227 140 114]
#   ...
#   [228 137 117]
#   [232 144 120]
#   [233 137 107]]]
# <PIL.Image.Image image mode=RGB size=50x50>

# %%
altered_image=image_array
altered_image[:100,:100]=210
print(f'The altered image is {altered_image}')
display(Image.fromarray(altered_image))
# Out:
# The altered image is [[[210 210 210]
#   [210 210 210]
#   [210 210 210]
#   ...
#   [230 148 122]
#   [221 130 110]
#   [200  99  90]]
#
#  [[210 210 210]
#   [210 210 210]
#   [210 210 210]
#   ...
#   [230 148 122]
#   [221 130 110]
#   [200  99  90]]
#
#  [[210 210 210]
#   [210 210 210]
#   [210 210 210]
#   ...
#   [230 148 122]
#   [221 130 110]
#   [200  99  90]]
#
#  ...
#
#  [[ 84  18  60]
#   [ 84  18  60]
#   [ 92  27  58]
#   ...
#   [173  73  84]
#   [172  68  76]
#   [177  62  79]]
#
#  [[ 82  22  57]
#   [ 82  22  57]
#   [ 96  32  62]
#   ...
#   [179  70  79]
#   [181  71  81]
#   [185  74  81]]
#
#  [[ 82  22  57]
#   [ 82  22  57]
#   [ 96  32  62]
#   ...
#   [179  70  79]
#   [181  71  81]
#   [185  74  81]]]
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
grey_img=Image.open("/content/drive/MyDrive/Ai Herald/worksheet_1/cameraman.png")
greyimg_arr=np.array(grey_img)
plt.imshow(greyimg_arr)

# %%
(row,column)=greyimg_arr.shape
mid=int(row/2)
crop=greyimg_arr[mid:mid+100,mid:mid+100]
plt.imshow(crop)

# %%
thresholdimg=np.where(greyimg_arr<100,0,np.where(greyimg_arr > 100, 255, greyimg_arr))
plt.imshow(thresholdimg)

# %%
rotated=grey_img.rotate(-90)
plt.imshow(rotated)

# %%
rgb=grey_img.convert('RGB')
plt.imshow(rgb)

# %%
gray_arr=np.array(grey_img)
centeredimg=gray_arr-np.mean(gray_arr)
cov_matrix=np.cov(centeredimg,rowvar=False)
print(cov_matrix)
# Out:
# [[543.51861775 520.97947881 492.56189228 ... 452.37668175 465.56655914
#   469.92323569]
#  [520.97947881 515.55188585 504.98165744 ... 438.16924535 451.13798771
#   455.28722786]
#  [492.56189228 504.98165744 514.61175621 ... 415.396557   428.0037075
#   431.84547762]
#  ...
#  [452.37668175 438.16924535 415.396557   ... 694.40484344 701.46153376
#   705.1383317 ]
#  [465.56655914 451.13798771 428.0037075  ... 701.46153376 724.80795927
#   732.40163283]
#  [469.92323569 455.28722786 431.84547762 ... 705.1383317  732.40163283
#   741.0831091 ]]

# %%
eigenvalues , eigenvectors = np . linalg . eigh ( cov_matrix )
sorted_indices = np . argsort ( eigenvalues ) [:: -1]
eigenvalues = eigenvalues [ sorted_indices ]
eigenvectors = eigenvectors [: , sorted_indices ]

# %%
explained_variance_ratio = eigenvalues / np .sum ( eigenvalues )
plt . plot ( np . cumsum ( explained_variance_ratio ) )
plt . title (" Cumulative Explained Variance ")
plt . xlabel (" Number of Components ")
plt . ylabel (" Cumulative Explained Variance ")
plt . grid ( True )
plt . show ()

# %%
k=50
components = eigenvectors [: , : k ]

# %%
compressed_data = np . dot ( centeredimg , components )

# %%
decompressed_data = np . dot ( compressed_data , components . T ) + np.mean(gray_arr)

# %%
plt.imshow(decompressed_data)
